# %%
import pandas as pd

#read csv file into python
df = pd.read_csv('pokemon_data.csv')

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
df['Total2'] = df['HP']+df['Attack']+df['Defense']+df['Sp. Atk']+df['Sp. Def']+df['Speed']

# %%
df.head(3)
# Out:
#    #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  1  Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 1  2    Ivysaur  Grass  Poison  60      62       63       80       80     60
# 2  3   Venusaur  Grass  Poison  80      82       83      100      100     80
#
#    Generation  Legendary  Total2
# 0           1      False     318
# 1           1      False     405
# 2           1      False     525

# %%
df.loc[df['Type 1']=='Grass']
# Out:
#        #                   Name Type 1    Type 2   HP  Attack  Defense  \
# 0      1              Bulbasaur  Grass    Poison   45      49       49
# 1      2                Ivysaur  Grass    Poison   60      62       63
# 2      3               Venusaur  Grass    Poison   80      82       83
# 3      3  VenusaurMega Venusaur  Grass    Poison   80     100      123
# 48    43                 Oddish  Grass    Poison   45      50       55
# ..   ...                    ...    ...       ...  ...     ...      ...
# 718  650                Chespin  Grass       NaN   56      61       65
# 719  651              Quilladin  Grass       NaN   61      78       95
# 720  652             Chesnaught  Grass  Fighting   88     107      122
# 740  672                 Skiddo  Grass       NaN   66      65       48
# 741  673                 Gogoat  Grass       NaN  123     100       62
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total2
# ...

# %% [markdown]
# # Filtering Data

# %%
df.loc[(df['Type 1']=='Grass') & (df['Type 2']=='Poison')]
# Out:
#        #                   Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 0      1              Bulbasaur  Grass  Poison   45      49       49       65
# 1      2                Ivysaur  Grass  Poison   60      62       63       80
# 2      3               Venusaur  Grass  Poison   80      82       83      100
# 3      3  VenusaurMega Venusaur  Grass  Poison   80     100      123      122
# 48    43                 Oddish  Grass  Poison   45      50       55       75
# 49    44                  Gloom  Grass  Poison   60      65       70       85
# 50    45              Vileplume  Grass  Poison   75      80       85      110
# 75    69             Bellsprout  Grass  Poison   50      75       35       70
# 76    70             Weepinbell  Grass  Poison   65      90       50       85
# 77    71             Victreebel  Grass  Poison   80     105       65      100
# 344  315                Roselia  Grass  Poison   50      60       45      100
# ...

# %%
df.loc[(df['Type 1']=='Grass') | (df['Type 2']=='Poison')]
# Out:
#        #                   Name Type 1    Type 2   HP  Attack  Defense  \
# 0      1              Bulbasaur  Grass    Poison   45      49       49
# 1      2                Ivysaur  Grass    Poison   60      62       63
# 2      3               Venusaur  Grass    Poison   80      82       83
# 3      3  VenusaurMega Venusaur  Grass    Poison   80     100      123
# 16    13                 Weedle    Bug    Poison   40      35       30
# ..   ...                    ...    ...       ...  ...     ...      ...
# 718  650                Chespin  Grass       NaN   56      61       65
# 719  651              Quilladin  Grass       NaN   61      78       95
# 720  652             Chesnaught  Grass  Fighting   88     107      122
# 740  672                 Skiddo  Grass       NaN   66      65       48
# 741  673                 Gogoat  Grass       NaN  123     100       62
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total2
# ...

# %%
new_df = df.loc[(df['Type 1']=='Grass') & (df['Type 2']=='Poison') & (df['HP']>80)]

# %%
new_df=new_df.reset_index()

# %%
new_df
# Out:
#    index    #       Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 0    652  591  Amoonguss  Grass  Poison  114      85       70       85
#
#    Sp. Def  Speed  Generation  Legendary  Total2
# 0       80     30           5      False     464

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total2
# 0         65       65     45           1      False     318
# ...

# %%
#names with mega in it
df.loc[df['Name'].str.contains('Mega')]
# Out:
#        #                       Name    Type 1    Type 2   HP  Attack  Defense  \
# 3      3      VenusaurMega Venusaur     Grass    Poison   80     100      123
# 7      6  CharizardMega Charizard X      Fire    Dragon   78     130      111
# 8      6  CharizardMega Charizard Y      Fire    Flying   78     104       78
# 12     9    BlastoiseMega Blastoise     Water       NaN   79     103      120
# 19    15      BeedrillMega Beedrill       Bug    Poison   65     150       40
# 23    18        PidgeotMega Pidgeot    Normal    Flying   83      80       80
# 71    65      AlakazamMega Alakazam   Psychic       NaN   55      50       65
# 87    80        SlowbroMega Slowbro     Water   Psychic   95      75      180
# 102   94          GengarMega Gengar     Ghost    Poison   60      65       80
# 124  115  KangaskhanMega Kangaskhan    Normal       NaN  105     125      100
# 137  127          PinsirMega Pinsir       Bug    Flying   65     155      120
# ...

# %%
#names without mega in it
df.loc[~df['Name'].str.contains('Mega')]
# Out:
#        #                 Name   Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 0      1            Bulbasaur    Grass  Poison   45      49       49       65
# 1      2              Ivysaur    Grass  Poison   60      62       63       80
# 2      3             Venusaur    Grass  Poison   80      82       83      100
# 4      4           Charmander     Fire     NaN   39      52       43       60
# 5      5           Charmeleon     Fire     NaN   58      64       58       80
# ..   ...                  ...      ...     ...  ...     ...      ...      ...
# 794  718     Zygarde50% Forme   Dragon  Ground  108     100      121       81
# 795  719              Diancie     Rock   Fairy   50     100      150      100
# 797  720  HoopaHoopa Confined  Psychic   Ghost   80     110       60      150
# 798  720   HoopaHoopa Unbound  Psychic    Dark   80     160       60      170
# 799  721            Volcanion     Fire   Water   80     110      120      130
#
# ...

# %%
#complicated filtering
import re
df.loc[df['Type 1'].str.contains('Fire|Grass', regex=True)]
# Out:
#        #                   Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 0      1              Bulbasaur  Grass  Poison   45      49       49       65
# 1      2                Ivysaur  Grass  Poison   60      62       63       80
# 2      3               Venusaur  Grass  Poison   80      82       83      100
# 3      3  VenusaurMega Venusaur  Grass  Poison   80     100      123      122
# 4      4             Charmander   Fire     NaN   39      52       43       60
# ..   ...                    ...    ...     ...  ...     ...      ...      ...
# 735  667                 Litleo   Fire  Normal   62      50       58       73
# 736  668                 Pyroar   Fire  Normal   86      68       72      109
# 740  672                 Skiddo  Grass     NaN   66      65       48       62
# 741  673                 Gogoat  Grass     NaN  123     100       62       97
# 799  721              Volcanion   Fire   Water   80     110      120      130
#
# ...

# %%
#ignore capitals
#df.loc[df['Type 1'].str.contains('fire|grass', flags=re.I regex=True)]
df.loc[df['Type 1'].str.contains('fire|grass',flags=re.I,regex=True)]
# Out:
#        #                   Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 0      1              Bulbasaur  Grass  Poison   45      49       49       65
# 1      2                Ivysaur  Grass  Poison   60      62       63       80
# 2      3               Venusaur  Grass  Poison   80      82       83      100
# 3      3  VenusaurMega Venusaur  Grass  Poison   80     100      123      122
# 4      4             Charmander   Fire     NaN   39      52       43       60
# ..   ...                    ...    ...     ...  ...     ...      ...      ...
# 735  667                 Litleo   Fire  Normal   62      50       58       73
# 736  668                 Pyroar   Fire  Normal   86      68       72      109
# 740  672                 Skiddo  Grass     NaN   66      65       48       62
# 741  673                 Gogoat  Grass     NaN  123     100       62       97
# 799  721              Volcanion   Fire   Water   80     110      120      130
#
# ...

# %%
df.loc[df['Name'].str.contains('pi[a-z]*',flags=re.I,regex=True)]
# Out:
#        #                     Name    Type 1    Type 2   HP  Attack  Defense  \
# 13    10                 Caterpie       Bug       NaN   45      30       35
# 20    16                   Pidgey    Normal    Flying   40      45       40
# 21    17                Pidgeotto    Normal    Flying   63      60       55
# 22    18                  Pidgeot    Normal    Flying   83      80       75
# 23    18      PidgeotMega Pidgeot    Normal    Flying   83      80       80
# 30    25                  Pikachu  Electric       NaN   35      55       40
# 42    37                   Vulpix      Fire       NaN   38      41       40
# 76    70               Weepinbell     Grass    Poison   65      90       50
# 84    78                 Rapidash      Fire       NaN   65     100       70
# 136  127                   Pinsir       Bug       NaN   65     125      100
# 137  127        PinsirMega Pinsir       Bug    Flying   65     155      120
# ...

# %%
df.loc[df['Name'].str.contains('^pi[a-z]*',flags=re.I,regex=True)]
# Out:
#        #                 Name    Type 1    Type 2   HP  Attack  Defense  \
# 20    16               Pidgey    Normal    Flying   40      45       40
# 21    17            Pidgeotto    Normal    Flying   63      60       55
# 22    18              Pidgeot    Normal    Flying   83      80       75
# 23    18  PidgeotMega Pidgeot    Normal    Flying   83      80       80
# 30    25              Pikachu  Electric       NaN   35      55       40
# 136  127               Pinsir       Bug       NaN   65     125      100
# 137  127    PinsirMega Pinsir       Bug    Flying   65     155      120
# 186  172                Pichu  Electric       NaN   20      40       15
# 219  204               Pineco       Bug       NaN   50      65       90
# 239  221            Piloswine       Ice    Ground  100     100       80
# 438  393               Piplup     Water       NaN   53      51       53
# 558  499              Pignite      Fire  Fighting   90      93       55
# ...

# %%
#change names of rows

# %%
df.loc[df['Type 1']=='Fire', 'Type 1']='Flamer'

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander   Flamer     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion   Flamer   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total2
# 0         65       65     45           1      False     318
# ...

# %%
df.loc[df['Total2']>500, ['Generation','Legendary']] ='Test Value'
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander   Flamer     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion   Flamer   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation   Legendary  Total2
# 0         65       65     45           1       False     318
# ...

# %%
df.loc[df['Total2']>500, ['Generation','Legendary']] =['Test Value','Test Two']

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander   Flamer     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion   Flamer   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation Legendary  Total2
# 0         65       65     45           1     False     318
# ...

# %%
df = pd.read_csv('modified.csv')

# %%
df
# Out:
#      Unnamed: 0    #                   Name   Type 1  Type 2  Total  HP  \
# 0             0    1              Bulbasaur    Grass  Poison    318  45
# 1             1    2                Ivysaur    Grass  Poison    405  60
# 2             2    3               Venusaur    Grass  Poison    525  80
# 3             3    3  VenusaurMega Venusaur    Grass  Poison    625  80
# 4             4    4             Charmander     Fire     NaN    309  39
# ..          ...  ...                    ...      ...     ...    ...  ..
# 795         795  719                Diancie     Rock   Fairy    600  50
# 796         796  719    DiancieMega Diancie     Rock   Fairy    700  50
# 797         797  720    HoopaHoopa Confined  Psychic   Ghost    600  80
# 798         798  720     HoopaHoopa Unbound  Psychic    Dark    680  80
# 799         799  721              Volcanion     Fire   Water    600  80
#
#      Defense  Attack  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %% [markdown]
# # Aggregate Statistics

# %%
df.groupby(['Type 1']).mean().sort_values('Defense', ascending=False)
# Out:
#           Unnamed: 0           #       Total         HP     Defense  \
# Type 1
# Steel     486.296296  442.851852  487.703704  65.222222  126.370370
# Rock      431.840909  392.727273  453.750000  65.363636  100.795455
# Dragon    521.843750  474.375000  550.531250  83.312500   86.375000
# Ground    392.312500  356.281250  437.500000  73.781250   84.843750
# Ghost     536.281250  486.500000  439.562500  64.437500   81.187500
# Water     333.312500  303.089286  430.455357  72.062500   72.946429
# Ice       465.666667  423.541667  433.458333  72.000000   71.416667
# Grass     380.414286  344.871429  421.142857  67.271429   70.800000
# Bug       368.072464  334.492754  378.927536  56.884058   70.724638
# Dark      507.387097  461.354839  445.741935  66.806452   70.225806
# Poison    278.285714  251.785714  399.142857  67.250000   68.821429
# Fire      360.942308  327.403846  458.076923  69.903846   67.769231
# Psychic   420.105263  380.807018  475.947368  70.631579   67.684211
# ...

# %%
df.groupby(['Type 1']).sum()
# Out:
#           Unnamed: 0      #  Total    HP  Defense  Attack  Sp. Atk  Sp. Def  \
# Type 1
# Bug            25397  23080  26146  3925     4880    4897     3717     4471
# Dark           15729  14302  13818  2071     2177    2740     2314     2155
# Dragon         16699  15180  17617  2666     2764    3588     3099     2843
# Electric       17626  15994  19510  2631     2917    3040     3961     3243
# Fairy           8407   7642   7024  1260     1117    1046     1335     1440
# Fighting       10812   9824  11244  1886     1780    2613     1434     1747
# Fire           18769  17025  23820  3635     3524    4408     4627     3755
# Flying          2986   2711   1940   283      265     315      377      290
# Ghost          17161  15568  14066  2062     2598    2361     2539     2447
# Grass          26629  24141  29480  4709     4956    5125     5425     4930
# Ground         12554  11401  14000  2361     2715    3064     1807     2008
# ...

# %%
df.groupby(['Type 1']).count().sort_values('Defense', ascending=False)
# Out:
#           Unnamed: 0    #  Name  Type 2  Total   HP  Defense  Attack  Sp. Atk  \
# Type 1
# Water            112  112   112      53    112  112      112     112      112
# Normal            98   98    98      37     98   98       98      98       98
# Grass             70   70    70      37     70   70       70      70       70
# Bug               69   69    69      52     69   69       69      69       69
# Psychic           57   57    57      19     57   57       57      57       57
# Fire              52   52    52      24     52   52       52      52       52
# Electric          44   44    44      17     44   44       44      44       44
# Rock              44   44    44      35     44   44       44      44       44
# Ghost             32   32    32      22     32   32       32      32       32
# Ground            32   32    32      19     32   32       32      32       32
# Dragon            32   32    32      21     32   32       32      32       32
# ...

# %%
df['count'] = 1
df.groupby(['Type 1']).count().sort_values('Defense', ascending=False)
# Out:
#           Unnamed: 0    #  Name  Type 2  Total   HP  Defense  Attack  Sp. Atk  \
# Type 1
# Water            112  112   112      53    112  112      112     112      112
# Normal            98   98    98      37     98   98       98      98       98
# Grass             70   70    70      37     70   70       70      70       70
# Bug               69   69    69      52     69   69       69      69       69
# Psychic           57   57    57      19     57   57       57      57       57
# Fire              52   52    52      24     52   52       52      52       52
# Electric          44   44    44      17     44   44       44      44       44
# Rock              44   44    44      35     44   44       44      44       44
# Ghost             32   32    32      22     32   32       32      32       32
# Ground            32   32    32      19     32   32       32      32       32
# Dragon            32   32    32      21     32   32       32      32       32
# ...

# %%
df['count'] = 1
df.groupby(['Type 1']).count()['count']
# Out:
# Type 1
# Bug          69
# Dark         31
# Dragon       32
# Electric     44
# Fairy        17
# Fighting     27
# Fire         52
# Flying        4
# Ghost        32
# Grass        70
# Ground       32
# Ice          24
# Normal       98
# Poison       28
# Psychic      57
# Rock         44
# Steel        27
# Water       112
# Name: count, dtype: int64

# %%
df['count'] = 1
df.groupby(['Type 1']).count()['HP']
# Out:
# Type 1
# Bug          69
# Dark         31
# Dragon       32
# Electric     44
# Fairy        17
# Fighting     27
# Fire         52
# Flying        4
# Ghost        32
# Grass        70
# Ground       32
# Ice          24
# Normal       98
# Poison       28
# Psychic      57
# Rock         44
# Steel        27
# Water       112
# Name: HP, dtype: int64

# %%
df['count'] = 1
df.groupby(['Type 1','Type 2']).count()['HP']
# Out:
# Type 1  Type 2
# Bug     Electric     2
#         Fighting     2
#         Fire         2
#         Flying      14
#         Ghost        1
#                     ..
# Water   Ice          3
#         Poison       3
#         Psychic      5
#         Rock         4
#         Steel        1
# Name: HP, Length: 136, dtype: int64
